# %%
# Import PySpark

from pyspark.sql import SparkSession
# import functions
from pyspark.sql.functions import countDistinct, col, when, collect_set, row_number, collect_list, lag, udf, sqrt, hour, minute, second, from_unixtime, to_timestamp, mean, max, min, first
from pyspark.sql.window import Window
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler
from pyspark.sql.types import ArrayType, DoubleType

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from enum import Enum
import seaborn as sns
import matplotlib.pyplot as plt
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# %%
# Create SparkSession
spark = SparkSession.builder \
                    .appName('csv-to-dataset') \
                    .config("spark.executor.memory", "4g") \
                    .getOrCreate()

# read a CSV file and convert it to a DataFrame
df = spark.read.csv('../data/Mouse_Event/Train_Mouse.csv', header=True, inferSchema=True)
df.show(3)
df.count()
# Out:
# +--------------------+--------------------+--------------------+-------------+----------+--------+--------+
# |                 uid|          session_id|             user_id|    timestamp|event_type|screen_x|screen_y|
# +--------------------+--------------------+--------------------+-------------+----------+--------+--------+
# |18d23c24-c5ea-46f...|c4af3096-5a73-4d7...|-2416201411472988629|1655993031186|         2|  1087.0|   442.0|
# |25f4ed5c-12d6-416...|c4af3096-5a73-4d7...|-2416201411472988629|1655993031135|         2|  1324.0|   468.0|
# |29716657-2778-4f3...|c4af3096-5a73-4d7...|-2416201411472988629|1655993031102|         2|  1504.0|   487.0|
# +--------------------+--------------------+--------------------+-------------+----------+--------+--------+
# only showing top 3 rows
# 11633

# %%
# functions

# get randon index of 6-lenth session id array
def get_valid_data_index():
    def distance(row):
        idx_valid = []
        i = random.sample(list(range(6)), 2)
        return row.session_ids[i[0]]
    return distance

# %%
# Dataset Prepare

new_df = StringIndexer(inputCol="user_id", outputCol="i") \
            .fit(df) \
            .transform(df) \
            .alias('new_df')
max_index = new_df.agg({"i": "max"}).collect()[0][0] + 1

new_df = new_df.withColumn("user_label", (new_df["i"] / max_index) * 20) \
        .withColumn("event_2", when(new_df["event_type"] == 2, 1).otherwise(0)) \
        .withColumn("event_3", when(new_df["event_type"] == 3, 1).otherwise(0)) \
        .withColumn("event_4", when(new_df["event_type"] == 4, 1).otherwise(0)) \
        .withColumn("event_5", when(new_df["event_type"] == 5, 1).otherwise(0)) \
        .withColumn("timestamp_", to_timestamp(from_unixtime(new_df["timestamp"]/1000))) \
        .withColumn("hour", hour("timestamp_")) \
        .withColumn("minute", minute("timestamp_")) \
        .withColumn("second", second("timestamp_"))

print(new_df.columns)

group_df = new_df.groupby('session_id', 'hour', 'minute', 'second') \
            .agg(mean("screen_x").alias("mean_screen_x"), \
                 mean("screen_y").alias("mean_screen_y"), \
                 mean("event_type").alias("mean_event_type"), \
                 mean("event_2").alias("mean_event_2"), \
                 mean("event_3").alias("mean_event_3"), \
                 mean("event_4").alias("mean_event_4"), \
                 mean("event_5").alias("mean_event_5"), \
                 (max("screen_x") - min("screen_x")).alias("diff_screen_x"), \
                 (max("screen_y") - min("screen_y")).alias("diff_screen_y"), \
                 (max("timestamp") - min("timestamp")).alias("diff_time"), \
                 # first("timestamp").alias("timestamp"), \
                 # first("user_label").alias("user_label"), \
                ) \
            .withColumn('distance_xy', sqrt(col('diff_screen_x')**2 + col('diff_screen_y')**2)) \
            .withColumn('second_speed_x', col('diff_screen_x') / col('diff_time')) \
            .withColumn('second_speed_y', col('diff_screen_y') / col('diff_time')) \
            .withColumn('second_speed_xy', col('distance_xy') / col('diff_time')) 
print(group_df.columns)

merged_df = new_df.join(group_df, on=['session_id', 'hour', 'minute', 'second']) \
                  .orderBy(["user_label", "timestamp"]) #, ascending=[True, True])
# Out:
# ['uid', 'session_id', 'user_id', 'timestamp', 'event_type', 'screen_x', 'screen_y', 'i', 'user_label', 'event_2', 'event_3', 'event_4', 'event_5', 'timestamp_', 'hour', 'minute', 'second']
# ['session_id', 'hour', 'minute', 'second', 'mean_screen_x', 'mean_screen_y', 'mean_event_type', 'mean_event_2', 'mean_event_3', 'mean_event_4', 'mean_event_5', 'diff_screen_x', 'diff_screen_y', 'diff_time', 'distance_xy', 'second_speed_x', 'second_speed_y', 'second_speed_xy']

# %%
# %%time
# get shift data

shift_values = range(1, 21)

for shift in shift_values:
    col_name_x = f"mean_screen_x_{shift}"
    col_name_y = f"mean_screen_y_{shift}"
    col_name_second_x = f"second_speed_x_{shift}"
    col_name_second_y = f"second_speed_y_{shift}"
    col_name_second_xy = f"second_speed_xy_{shift}"
    col_name_event_type = f"mean_event_type_{shift}"
    merged_df = merged_df.withColumn(col_name_x, lag("mean_screen_x", shift).over(Window.partitionBy("session_id").orderBy("timestamp"))) \
                         .withColumn(col_name_y, lag("mean_screen_y", shift).over(Window.partitionBy("session_id").orderBy("timestamp"))) \
                         .withColumn(col_name_second_x, lag("second_speed_x", shift).over(Window.partitionBy("session_id").orderBy("timestamp"))) \
                         .withColumn(col_name_second_y, lag("second_speed_y", shift).over(Window.partitionBy("session_id").orderBy("timestamp"))) \
                         .withColumn(col_name_second_xy, lag("second_speed_xy", shift).over(Window.partitionBy("session_id").orderBy("timestamp"))) \
                         .withColumn(col_name_event_type, lag("mean_event_type", shift).over(Window.partitionBy("session_id").orderBy("timestamp"))) \

# merged_df = group_df.orderBy(["user_label", "timestamp"]).dropna()
merged_df.select('session_id', 'timestamp', 'hour', 'minute', 'second', 'mean_screen_x', 'mean_screen_x_1', 'mean_screen_x_2') \
        .show(10)
# Out:
# +--------------------+-------------+----+------+------+-----------------+---------------+---------------+
# |          session_id|    timestamp|hour|minute|second|    mean_screen_x|mean_screen_x_1|mean_screen_x_2|
# +--------------------+-------------+----+------+------+-----------------+---------------+---------------+
# |018a54bb-b6d0-4d4...|1656339827092|  16|    23|    47|            964.0|           null|           null|
# |018a54bb-b6d0-4d4...|1656339827521|  16|    23|    47|            964.0|          964.0|           null|
# |018a54bb-b6d0-4d4...|1656339827541|  16|    23|    47|            964.0|          964.0|          964.0|
# |018a54bb-b6d0-4d4...|1656339827574|  16|    23|    47|            964.0|          964.0|          964.0|
# |018a54bb-b6d0-4d4...|1656339827758|  16|    23|    47|            964.0|          964.0|          964.0|
# |018a54bb-b6d0-4d4...|1656339827841|  16|    23|    47|            964.0|          964.0|          964.0|
# |018a54bb-b6d0-4d4...|1656339833170|  16|    23|    53|            699.2|          964.0|          964.0|
# |018a54bb-b6d0-4d4...|1656368275913|   0|    17|    55|            652.4|          699.2|          964.0|
# |018a54bb-b6d0-4d4...|1656368275978|   0|    17|    55|            652.4|          652.4|          699.2|
# |018a54bb-b6d0-4d4...|1656368276129|   0|    17|    56|576.5333533333334|          652.4|          652.4|
# +--------------------+-------------+----+------+------+-----------------+---------------+---------------+
# only showing top 10 rows
#
# CPU times: user 353 ms, sys: 108 ms, total: 462 ms
# Wall time: 14.9 s

# %% [markdown]
# # Normalizaton

# %%
train_features = [
    'mean_event_2', 'mean_event_3', 'mean_event_4', 'mean_event_5',
    'mean_screen_x',   'mean_screen_y',   'mean_event_type',   'second_speed_x',   'second_speed_y',   'second_speed_xy',
]

for i in range(1, 21):
    train_features.append('mean_screen_x_'+str(i))
    train_features.append('mean_screen_y_'+str(i))
    train_features.append('second_speed_x_'+str(i))
    train_features.append('second_speed_y_'+str(i))
    train_features.append('second_speed_xy_'+str(i))
    train_features.append('mean_event_type_'+str(i))

assembler = VectorAssembler(inputCols=train_features, outputCol='features')
data = assembler.transform(merged_df.dropna().na.fill(0))

# Normalize the vector column
scaler = StandardScaler(inputCol='features', outputCol='scaled_features')
scaler_model = scaler.fit(data)
data = scaler_model.transform(data)

# %% [markdown]
# # Split the Train and Valid dataset

# %%
# %%time
dfi = df.groupby('user_id').agg(collect_set("session_id").alias("session_ids"))
rows = dfi.withColumn('for_valid', get_valid_data_index()(dfi)).select('for_valid').collect()
valid_index = list(np.array([row[0] for row in rows]))

valid_df = data.filter(col('session_id').isin(valid_index))
train_df = data.subtract(valid_df)

train_df.count(), valid_df.count()
# Out:
# CPU times: user 19.1 ms, sys: 8.09 ms, total: 27.2 ms
# Wall time: 14.3 s
# (3886, 831)

# %%
# %%time

df_1_x = train_df.select(train_features).toPandas().to_numpy()
df_1_y = train_df.select('user_label').toPandas().to_numpy()[:,0]

df_2_x = valid_df.select(train_features).toPandas().to_numpy()
df_2_y = valid_df.select('user_label').toPandas().to_numpy()[:,0]

df_1_x.shape, df_1_y.shape
df_2_x.shape, df_2_y.shape
# Out:
# CPU times: user 433 ms, sys: 211 ms, total: 644 ms
# Wall time: 20 s
# ((831, 130), (831,))

# %% [markdown]
# # NN

# %%
# Simple NN model
class MyModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(MyModel, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.dropout = nn.Dropout(0.5)
        # self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        # out = self.fc3(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.fc4(out)
        return out
    
    def compute_loss(self, output, target):
        loss = nn.CrossEntropyLoss()
        return loss(output, target)

# %%
train_tensor_x = torch.tensor(df_1_x, dtype=torch.float)
train_tensor_y = torch.tensor(df_1_y, dtype=torch.float)
train_ds = TensorDataset(train_tensor_x, train_tensor_y)

valid_tensor_x = torch.tensor(df_2_x, dtype=torch.float)
valid_tensor_y = torch.tensor(df_2_y, dtype=torch.float)
valid_ds = TensorDataset(valid_tensor_x, valid_tensor_y)

batch_size = 516
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=False)

# %%
model_NN = MyModel(df_1_x.shape[1], 512, 20)

# %%
# define your loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model_NN.parameters())

model_NN.train()
train_losses = []
valid_losses = []
num_epochs = 1000
best_loss = float('inf')
patience = 10
counter = 0

for epoch in range(num_epochs):
    running_loss = 0.0
    model_NN.train()
    for batch_x, batch_y in train_loader:
        # Clear the gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model_NN(batch_x.float())

        # Compute the loss
        # loss = criterion(outputs, batch_y)
        loss = model_NN.compute_loss(outputs, batch_y.long())
        running_loss += loss.item()

        # Backward pass
        loss.backward()

        # Update the parameters
        optimizer.step()
    

    # Print the loss
    avg_loss_t = running_loss / len(train_loader)
    train_losses.append(avg_loss_t)
    # print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {avg_loss_t:.4f}")

    model_NN.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_x, batch_y in valid_loader:
            outputs = model_NN(batch_x.float())
            loss = criterion(outputs, batch_y.long())
            val_loss += loss.item() # * batch_x.size(0)
    avg_loss_v = val_loss / len(valid_loader)
    valid_losses.append(avg_loss_v)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {avg_loss_t:.4f}, Valid Loss: {avg_loss_v:.4f}")

    # check is validation loss has improved
    if avg_loss_v < best_loss:
        best_loss = avg_loss_v
        counter = 0
    else:
        counter += 1
    
    # check if early stopping criteria has been met 
    if counter >= patience:
        print(f"Validation loss did not improve for {patience} epochs. Stopping early...")
        break
# Out:
# Epoch 1/1000, Train Loss: 59.4163, Valid Loss: 14.2259
# Epoch 2/1000, Train Loss: 9.2002, Valid Loss: 2.8192
# Epoch 3/1000, Train Loss: 2.8989, Valid Loss: 2.6956
# Epoch 4/1000, Train Loss: 2.7215, Valid Loss: 2.5870
# Epoch 5/1000, Train Loss: 2.6732, Valid Loss: 2.5914
# Epoch 6/1000, Train Loss: 2.6356, Valid Loss: 2.4536
# Epoch 7/1000, Train Loss: 2.6088, Valid Loss: 2.4749
# Epoch 8/1000, Train Loss: 2.5543, Valid Loss: 2.4068
# Epoch 9/1000, Train Loss: 2.5093, Valid Loss: 2.3642
# Epoch 10/1000, Train Loss: 2.4850, Valid Loss: 2.3193
# Epoch 11/1000, Train Loss: 2.4610, Valid Loss: 2.2788
# Epoch 12/1000, Train Loss: 2.4370, Valid Loss: 2.2270
# Epoch 13/1000, Train Loss: 2.4100, Valid Loss: 2.2098
# Epoch 14/1000, Train Loss: 2.3705, Valid Loss: 2.1750
# Epoch 15/1000, Train Loss: 2.3458, Valid Loss: 2.1677
# Epoch 16/1000, Train Loss: 2.3069, Valid Loss: 2.1241
# Epoch 17/1000, Train Loss: 2.3015, Valid Loss: 2.1057
# Epoch 18/1000, Train Loss: 2.2846, Valid Loss: 2.0909
# Epoch 19/1000, Train Loss: 2.2566, Valid Loss: 2.0506
# Epoch 20/1000, Train Loss: 2.2321, Valid Loss: 2.0589
# Epoch 21/1000, Train Loss: 2.2189, Valid Loss: 2.0523
# Epoch 22/1000, Train Loss: 2.2269, Valid Loss: 2.0355
# Epoch 23/1000, Train Loss: 2.2272, Valid Loss: 2.0106
# Epoch 24/1000, Train Loss: 2.2009, Valid Loss: 2.0184
# Epoch 25/1000, Train Loss: 2.1890, Valid Loss: 1.9911
# Epoch 26/1000, Train Loss: 2.1844, Valid Loss: 1.9674
# Epoch 27/1000, Train Loss: 2.1826, Valid Loss: 1.9558
# Epoch 28/1000, Train Loss: 2.1485, Valid Loss: 1.9310
# Epoch 29/1000, Train Loss: 2.1386, Valid Loss: 1.9315
# Epoch 30/1000, Train Loss: 2.1435, Valid Loss: 1.9173
# Epoch 31/1000, Train Loss: 2.1268, Valid Loss: 1.9048
# Epoch 32/1000, Train Loss: 2.1087, Valid Loss: 1.8773
# Epoch 33/1000, Train Loss: 2.0768, Valid Loss: 1.8738
# Epoch 34/1000, Train Loss: 2.0982, Valid Loss: 1.8712
# Epoch 35/1000, Train Loss: 2.0626, Valid Loss: 1.8165
# Epoch 36/1000, Train Loss: 2.0377, Valid Loss: 1.8032
# Epoch 37/1000, Train Loss: 2.0529, Valid Loss: 1.8076
# Epoch 38/1000, Train Loss: 2.0166, Valid Loss: 1.7985
# Epoch 39/1000, Train Loss: 2.0299, Valid Loss: 1.8071
# Epoch 40/1000, Train Loss: 2.0352, Valid Loss: 1.7848
# Epoch 41/1000, Train Loss: 2.0245, Valid Loss: 1.7728
# Epoch 42/1000, Train Loss: 2.0034, Valid Loss: 1.7662
# Epoch 43/1000, Train Loss: 1.9839, Valid Loss: 1.7323
# Epoch 44/1000, Train Loss: 1.9683, Valid Loss: 1.7453
# Epoch 45/1000, Train Loss: 1.9570, Valid Loss: 1.7099
# Epoch 46/1000, Train Loss: 1.9772, Valid Loss: 1.7042
# Epoch 47/1000, Train Loss: 1.9618, Valid Loss: 1.7084
# Epoch 48/1000, Train Loss: 1.9482, Valid Loss: 1.6871
# Epoch 49/1000, Train Loss: 1.9370, Valid Loss: 1.7066
# Epoch 50/1000, Train Loss: 1.9349, Valid Loss: 1.6672
# Epoch 51/1000, Train Loss: 1.9024, Valid Loss: 1.6290
# Epoch 52/1000, Train Loss: 1.9043, Valid Loss: 1.6443
# Epoch 53/1000, Train Loss: 1.8864, Valid Loss: 1.6170
# Epoch 54/1000, Train Loss: 1.8637, Valid Loss: 1.5733
# Epoch 55/1000, Train Loss: 1.8785, Valid Loss: 1.5999
# Epoch 56/1000, Train Loss: 1.8539, Valid Loss: 1.6117
# Epoch 57/1000, Train Loss: 1.8661, Valid Loss: 1.5795
# Epoch 58/1000, Train Loss: 1.8763, Valid Loss: 1.6109
# Epoch 59/1000, Train Loss: 1.8871, Valid Loss: 1.6294
# Epoch 60/1000, Train Loss: 1.8849, Valid Loss: 1.5910
# Epoch 61/1000, Train Loss: 1.8402, Valid Loss: 1.5707
# Epoch 62/1000, Train Loss: 1.8451, Valid Loss: 1.5539
# Epoch 63/1000, Train Loss: 1.8217, Valid Loss: 1.5217
# Epoch 64/1000, Train Loss: 1.8158, Valid Loss: 1.5356
# Epoch 65/1000, Train Loss: 1.8178, Valid Loss: 1.5414
# Epoch 66/1000, Train Loss: 1.7956, Valid Loss: 1.5094
# Epoch 67/1000, Train Loss: 1.7844, Valid Loss: 1.4921
# Epoch 68/1000, Train Loss: 1.7857, Valid Loss: 1.4630
# Epoch 69/1000, Train Loss: 1.7834, Valid Loss: 1.4606
# Epoch 70/1000, Train Loss: 1.7508, Valid Loss: 1.4498
# Epoch 71/1000, Train Loss: 1.7805, Valid Loss: 1.4776
# Epoch 72/1000, Train Loss: 1.7876, Valid Loss: 1.4507
# Epoch 73/1000, Train Loss: 1.7596, Valid Loss: 1.4372
# Epoch 74/1000, Train Loss: 1.7534, Valid Loss: 1.4162
# Epoch 75/1000, Train Loss: 1.7069, Valid Loss: 1.4021
# Epoch 76/1000, Train Loss: 1.7094, Valid Loss: 1.4136
# Epoch 77/1000, Train Loss: 1.7304, Valid Loss: 1.4292
# Epoch 78/1000, Train Loss: 1.7117, Valid Loss: 1.4247
# Epoch 79/1000, Train Loss: 1.7063, Valid Loss: 1.3693
# Epoch 80/1000, Train Loss: 1.7136, Valid Loss: 1.3874
# Epoch 81/1000, Train Loss: 1.6947, Valid Loss: 1.3480
# Epoch 82/1000, Train Loss: 1.6787, Valid Loss: 1.3392
# Epoch 83/1000, Train Loss: 1.7029, Valid Loss: 1.3487
# Epoch 84/1000, Train Loss: 1.6696, Valid Loss: 1.3538
# Epoch 85/1000, Train Loss: 1.6397, Valid Loss: 1.2934
# Epoch 86/1000, Train Loss: 1.6495, Valid Loss: 1.3262
# Epoch 87/1000, Train Loss: 1.6454, Valid Loss: 1.2894
# Epoch 88/1000, Train Loss: 1.6376, Valid Loss: 1.2668
# Epoch 89/1000, Train Loss: 1.5968, Valid Loss: 1.2759
# Epoch 90/1000, Train Loss: 1.6317, Valid Loss: 1.2639
# Epoch 91/1000, Train Loss: 1.6203, Valid Loss: 1.2629
# Epoch 92/1000, Train Loss: 1.5941, Valid Loss: 1.2540
# Epoch 93/1000, Train Loss: 1.5881, Valid Loss: 1.2552
# Epoch 94/1000, Train Loss: 1.5783, Valid Loss: 1.2344
# Epoch 95/1000, Train Loss: 1.6050, Valid Loss: 1.2552
# Epoch 96/1000, Train Loss: 1.5955, Valid Loss: 1.2403
# Epoch 97/1000, Train Loss: 1.5970, Valid Loss: 1.2248
# Epoch 98/1000, Train Loss: 1.5732, Valid Loss: 1.1794
# Epoch 99/1000, Train Loss: 1.5785, Valid Loss: 1.2295
# Epoch 100/1000, Train Loss: 1.5675, Valid Loss: 1.1952
# Epoch 101/1000, Train Loss: 1.5949, Valid Loss: 1.2200
# Epoch 102/1000, Train Loss: 1.5665, Valid Loss: 1.1735
# Epoch 103/1000, Train Loss: 1.5375, Valid Loss: 1.2015
# Epoch 104/1000, Train Loss: 1.5390, Valid Loss: 1.1380
# Epoch 105/1000, Train Loss: 1.5220, Valid Loss: 1.1531
# Epoch 106/1000, Train Loss: 1.5217, Valid Loss: 1.1588
# Epoch 107/1000, Train Loss: 1.5004, Valid Loss: 1.1148
# Epoch 108/1000, Train Loss: 1.5060, Valid Loss: 1.1566
# Epoch 109/1000, Train Loss: 1.4919, Valid Loss: 1.1067
# Epoch 110/1000, Train Loss: 1.4889, Valid Loss: 1.1316
# Epoch 111/1000, Train Loss: 1.4946, Valid Loss: 1.1096
# Epoch 112/1000, Train Loss: 1.4689, Valid Loss: 1.1004
# Epoch 113/1000, Train Loss: 1.4851, Valid Loss: 1.1205
# Epoch 114/1000, Train Loss: 1.4890, Valid Loss: 1.0731
# Epoch 115/1000, Train Loss: 1.4575, Valid Loss: 1.0957
# Epoch 116/1000, Train Loss: 1.4515, Valid Loss: 1.0411
# Epoch 117/1000, Train Loss: 1.4327, Valid Loss: 1.0591
# Epoch 118/1000, Train Loss: 1.4553, Valid Loss: 1.0505
# Epoch 119/1000, Train Loss: 1.4124, Valid Loss: 1.0059
# Epoch 120/1000, Train Loss: 1.4330, Valid Loss: 1.0050
# Epoch 121/1000, Train Loss: 1.4068, Valid Loss: 1.0255
# Epoch 122/1000, Train Loss: 1.4138, Valid Loss: 0.9981
# Epoch 123/1000, Train Loss: 1.3911, Valid Loss: 0.9967
# Epoch 124/1000, Train Loss: 1.3780, Valid Loss: 0.9571
# Epoch 125/1000, Train Loss: 1.3933, Valid Loss: 0.9961
# Epoch 126/1000, Train Loss: 1.3821, Valid Loss: 0.9498
# Epoch 127/1000, Train Loss: 1.3660, Valid Loss: 0.9686
# Epoch 128/1000, Train Loss: 1.3511, Valid Loss: 0.9507
# Epoch 129/1000, Train Loss: 1.3409, Valid Loss: 0.9499
# Epoch 130/1000, Train Loss: 1.3338, Valid Loss: 0.9281
# Epoch 131/1000, Train Loss: 1.3427, Valid Loss: 0.9083
# Epoch 132/1000, Train Loss: 1.3347, Valid Loss: 0.8883
# Epoch 133/1000, Train Loss: 1.3160, Valid Loss: 0.9232
# Epoch 134/1000, Train Loss: 1.3356, Valid Loss: 0.9401
# Epoch 135/1000, Train Loss: 1.3306, Valid Loss: 0.9305
# Epoch 136/1000, Train Loss: 1.3038, Valid Loss: 0.8665
# Epoch 137/1000, Train Loss: 1.2580, Valid Loss: 0.8484
# Epoch 138/1000, Train Loss: 1.2930, Valid Loss: 0.8801
# Epoch 139/1000, Train Loss: 1.2525, Valid Loss: 0.8398
# Epoch 140/1000, Train Loss: 1.2559, Valid Loss: 0.8468
# Epoch 141/1000, Train Loss: 1.2446, Valid Loss: 0.8150
# Epoch 142/1000, Train Loss: 1.2651, Valid Loss: 0.8564
# Epoch 143/1000, Train Loss: 1.2787, Valid Loss: 0.8260
# Epoch 144/1000, Train Loss: 1.2672, Valid Loss: 0.8537
# Epoch 145/1000, Train Loss: 1.2522, Valid Loss: 0.8312
# Epoch 146/1000, Train Loss: 1.2469, Valid Loss: 0.8300
# Epoch 147/1000, Train Loss: 1.2437, Valid Loss: 0.8463
# Epoch 148/1000, Train Loss: 1.2178, Valid Loss: 0.8327
# Epoch 149/1000, Train Loss: 1.2299, Valid Loss: 0.7832
# Epoch 150/1000, Train Loss: 1.2068, Valid Loss: 0.7823
# Epoch 151/1000, Train Loss: 1.2014, Valid Loss: 0.7857
# Epoch 152/1000, Train Loss: 1.2088, Valid Loss: 0.7817
# Epoch 153/1000, Train Loss: 1.1791, Valid Loss: 0.7566
# Epoch 154/1000, Train Loss: 1.2043, Valid Loss: 0.7559
# Epoch 155/1000, Train Loss: 1.1515, Valid Loss: 0.7662
# Epoch 156/1000, Train Loss: 1.1557, Valid Loss: 0.7467
# Epoch 157/1000, Train Loss: 1.1715, Valid Loss: 0.7462
# Epoch 158/1000, Train Loss: 1.1776, Valid Loss: 0.7766
# Epoch 159/1000, Train Loss: 1.1486, Valid Loss: 0.7192
# Epoch 160/1000, Train Loss: 1.1788, Valid Loss: 0.7573
# Epoch 161/1000, Train Loss: 1.1412, Valid Loss: 0.7134
# Epoch 162/1000, Train Loss: 1.1213, Valid Loss: 0.6896
# Epoch 163/1000, Train Loss: 1.1373, Valid Loss: 0.7215
# Epoch 164/1000, Train Loss: 1.1422, Valid Loss: 0.6902
# Epoch 165/1000, Train Loss: 1.1496, Valid Loss: 0.7259
# Epoch 166/1000, Train Loss: 1.1317, Valid Loss: 0.7057
# Epoch 167/1000, Train Loss: 1.1515, Valid Loss: 0.7395
# Epoch 168/1000, Train Loss: 1.1292, Valid Loss: 0.6731
# Epoch 169/1000, Train Loss: 1.0876, Valid Loss: 0.6673
# Epoch 170/1000, Train Loss: 1.0914, Valid Loss: 0.6594
# Epoch 171/1000, Train Loss: 1.0613, Valid Loss: 0.6531
# Epoch 172/1000, Train Loss: 1.0708, Valid Loss: 0.6818
# Epoch 173/1000, Train Loss: 1.0751, Valid Loss: 0.6193
# Epoch 174/1000, Train Loss: 1.0956, Valid Loss: 0.6972
# Epoch 175/1000, Train Loss: 1.0786, Valid Loss: 0.6353
# Epoch 176/1000, Train Loss: 1.0258, Valid Loss: 0.6106
# Epoch 177/1000, Train Loss: 1.0387, Valid Loss: 0.6259
# Epoch 178/1000, Train Loss: 1.0230, Valid Loss: 0.6116
# Epoch 179/1000, Train Loss: 0.9885, Valid Loss: 0.5959
# Epoch 180/1000, Train Loss: 1.0168, Valid Loss: 0.5676
# Epoch 181/1000, Train Loss: 0.9937, Valid Loss: 0.5761
# Epoch 182/1000, Train Loss: 1.0023, Valid Loss: 0.6012
# Epoch 183/1000, Train Loss: 1.0107, Valid Loss: 0.6004
# Epoch 184/1000, Train Loss: 1.0165, Valid Loss: 0.5631
# Epoch 185/1000, Train Loss: 0.9943, Valid Loss: 0.5830
# Epoch 186/1000, Train Loss: 1.0130, Valid Loss: 0.5889
# Epoch 187/1000, Train Loss: 0.9924, Valid Loss: 0.5924
# Epoch 188/1000, Train Loss: 1.0039, Valid Loss: 0.5783
# Epoch 189/1000, Train Loss: 0.9935, Valid Loss: 0.6166
# Epoch 190/1000, Train Loss: 1.0121, Valid Loss: 0.5740
# Epoch 191/1000, Train Loss: 0.9760, Valid Loss: 0.5478
# Epoch 192/1000, Train Loss: 0.9732, Valid Loss: 0.5796
# Epoch 193/1000, Train Loss: 0.9935, Valid Loss: 0.5608
# Epoch 194/1000, Train Loss: 0.9898, Valid Loss: 0.5780
# Epoch 195/1000, Train Loss: 0.9480, Valid Loss: 0.5323
# Epoch 196/1000, Train Loss: 0.9451, Valid Loss: 0.5620
# Epoch 197/1000, Train Loss: 0.9395, Valid Loss: 0.5096
# Epoch 198/1000, Train Loss: 0.9096, Valid Loss: 0.5129
# Epoch 199/1000, Train Loss: 0.9131, Valid Loss: 0.5122
# Epoch 200/1000, Train Loss: 0.9235, Valid Loss: 0.4953
# Epoch 201/1000, Train Loss: 0.9318, Valid Loss: 0.5085
# Epoch 202/1000, Train Loss: 0.9278, Valid Loss: 0.5233
# Epoch 203/1000, Train Loss: 0.9159, Valid Loss: 0.5010
# Epoch 204/1000, Train Loss: 0.9239, Valid Loss: 0.4927
# Epoch 205/1000, Train Loss: 0.9140, Valid Loss: 0.4860
# Epoch 206/1000, Train Loss: 0.8897, Valid Loss: 0.4598
# Epoch 207/1000, Train Loss: 0.8789, Valid Loss: 0.4982
# Epoch 208/1000, Train Loss: 0.8811, Valid Loss: 0.4532
# Epoch 209/1000, Train Loss: 0.8696, Valid Loss: 0.4761
# Epoch 210/1000, Train Loss: 0.8649, Valid Loss: 0.4596
# Epoch 211/1000, Train Loss: 0.9033, Valid Loss: 0.4811
# Epoch 212/1000, Train Loss: 0.9087, Valid Loss: 0.5007
# Epoch 213/1000, Train Loss: 0.9077, Valid Loss: 0.4731
# Epoch 214/1000, Train Loss: 0.8890, Valid Loss: 0.4740
# Epoch 215/1000, Train Loss: 0.8740, Valid Loss: 0.4708
# Epoch 216/1000, Train Loss: 0.8644, Valid Loss: 0.4495
# Epoch 217/1000, Train Loss: 0.8509, Valid Loss: 0.4386
# Epoch 218/1000, Train Loss: 0.8478, Valid Loss: 0.4278
# Epoch 219/1000, Train Loss: 0.7980, Valid Loss: 0.4100
# Epoch 220/1000, Train Loss: 0.7949, Valid Loss: 0.4060
# Epoch 221/1000, Train Loss: 0.8111, Valid Loss: 0.4095
# Epoch 222/1000, Train Loss: 0.8183, Valid Loss: 0.4117
# Epoch 223/1000, Train Loss: 0.8390, Valid Loss: 0.4306
# Epoch 224/1000, Train Loss: 0.8192, Valid Loss: 0.4202
# Epoch 225/1000, Train Loss: 0.7857, Valid Loss: 0.3832
# Epoch 226/1000, Train Loss: 0.8033, Valid Loss: 0.4110
# Epoch 227/1000, Train Loss: 0.7569, Valid Loss: 0.3767
# Epoch 228/1000, Train Loss: 0.7495, Valid Loss: 0.3762
# Epoch 229/1000, Train Loss: 0.7793, Valid Loss: 0.3646
# Epoch 230/1000, Train Loss: 0.7745, Valid Loss: 0.3775
# Epoch 231/1000, Train Loss: 0.7523, Valid Loss: 0.3593
# Epoch 232/1000, Train Loss: 0.7495, Valid Loss: 0.3487
# Epoch 233/1000, Train Loss: 0.7229, Valid Loss: 0.3445
# Epoch 234/1000, Train Loss: 0.7466, Valid Loss: 0.3729
# Epoch 235/1000, Train Loss: 0.7494, Valid Loss: 0.3582
# Epoch 236/1000, Train Loss: 0.7433, Valid Loss: 0.3452
# Epoch 237/1000, Train Loss: 0.7380, Valid Loss: 0.3375
# Epoch 238/1000, Train Loss: 0.7348, Valid Loss: 0.3459
# Epoch 239/1000, Train Loss: 0.6969, Valid Loss: 0.3330
# Epoch 240/1000, Train Loss: 0.6936, Valid Loss: 0.3147
# Epoch 241/1000, Train Loss: 0.6837, Valid Loss: 0.3124
# Epoch 242/1000, Train Loss: 0.6902, Valid Loss: 0.3415
# Epoch 243/1000, Train Loss: 0.7166, Valid Loss: 0.3280
# Epoch 244/1000, Train Loss: 0.7141, Valid Loss: 0.3399
# Epoch 245/1000, Train Loss: 0.7030, Valid Loss: 0.3313
# Epoch 246/1000, Train Loss: 0.6958, Valid Loss: 0.2961
# Epoch 247/1000, Train Loss: 0.6730, Valid Loss: 0.3006
# Epoch 248/1000, Train Loss: 0.6982, Valid Loss: 0.3343
# Epoch 249/1000, Train Loss: 0.6754, Valid Loss: 0.3055
# Epoch 250/1000, Train Loss: 0.6895, Valid Loss: 0.3094
# Epoch 251/1000, Train Loss: 0.6885, Valid Loss: 0.3275
# Epoch 252/1000, Train Loss: 0.7054, Valid Loss: 0.3311
# Epoch 253/1000, Train Loss: 0.7314, Valid Loss: 0.3461
# Epoch 254/1000, Train Loss: 0.7102, Valid Loss: 0.3225
# Epoch 255/1000, Train Loss: 0.6818, Valid Loss: 0.3015
# Epoch 256/1000, Train Loss: 0.6957, Valid Loss: 0.2981
# Validation loss did not improve for 10 epochs. Stopping early...

# %% [markdown]
# # Check Proformance

# %%
from sklearn.metrics import classification_report

model_NN.eval()

predict_train_y = np.argmax(model_NN(train_tensor_x).detach().numpy(), axis=1)
print(f"confusion matrix on train dataset: \n {classification_report(train_tensor_y, predict_train_y)}")

predict_valid_y = np.argmax(model_NN(valid_tensor_x).detach().numpy(), axis=1)
print(f"confusion matrix on valid dataset: \n {classification_report(valid_tensor_y, predict_valid_y)}")
# Out:
# confusion matrix on train dataset:
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.91      0.87       391
#          1.0       0.93      0.83      0.88       320
#          2.0       0.95      0.78      0.86       332
#          3.0       0.79      0.97      0.87       403
#          4.0       1.00      1.00      1.00       323
#          5.0       0.83      0.88      0.85       297
#          6.0       0.96      0.84      0.90       123
#          7.0       0.90      0.90      0.90       136
#          8.0       0.96      0.92      0.94       146
#          9.0       1.00      1.00      1.00        60
#         10.0       0.99      0.93      0.96       197
#         11.0       1.00      0.97      0.98       145
#         12.0       0.95      0.95      0.95       278
#         13.0       1.00      0.87      0.93        67
#         14.0       0.99      0.98      0.98        92
#         15.0       0.91      0.91      0.91       158
#         16.0       1.00      1.00      1.00       113
#         17.0       0.95      0.92      0.93       180
#         18.0       1.00      1.00      1.00        60
#         19.0       0.97      0.98      0.98        65
#
#     accuracy                           0.92      3886
#    macro avg       0.95      0.93      0.93      3886
# weighted avg       0.92      0.92      0.92      3886
#
# confusion matrix on valid dataset:
#                precision    recall  f1-score   support
#
#          0.0       0.35      0.41      0.38       104
#          1.0       0.42      0.47      0.45        78
#          2.0       0.26      0.17      0.21        94
#          3.0       0.22      0.41      0.29        88
#          4.0       0.51      1.00      0.68        24
#          5.0       0.23      0.44      0.30        68
#          6.0       0.14      0.03      0.05        34
#          7.0       0.08      0.06      0.07        32
#          8.0       0.54      0.13      0.21        53
#          9.0       0.00      0.00      0.00         0
#         10.0       0.00      0.00      0.00        13
#         11.0       0.00      0.00      0.00        43
#         12.0       0.37      0.21      0.27        82
#         13.0       0.00      0.00      0.00        19
#         14.0       0.00      0.00      0.00         0
#         15.0       0.00      0.00      0.00        45
#         16.0       0.67      0.50      0.57         8
#         17.0       0.00      0.00      0.00        15
#         18.0       0.36      0.57      0.44         7
#         19.0       0.56      0.21      0.30        24
#
#     accuracy                           0.27       831
#    macro avg       0.24      0.23      0.21       831
# weighted avg       0.28      0.27      0.25       831
